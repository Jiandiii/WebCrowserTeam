# %%
#将用户原始信息的json分为地区分布.json和年龄分布.json
#所有原始json需放在同一路径下

import json
import os
import pandas as pd
import numpy as np
path=#'D:/pythonProject/test/venv'
for i in os.listdir(path):
    print(i)
    try:
        filename=path+i
        with open(filename) as file_obj:
            list=json.load(file_obj)
        uid=list[0]
        age=list[1]
        location=list[2]
        df=pd.DataFrame({'uid':uid,'age':age,'location':location})
        df=df.drop_duplicates()
        new_age=df['age'].copy()
        new_location=df['location'].copy()
        for n in new_location.index:
            if new_location[n]==1000000:
                new_location[n]='海外'
            if new_location[n]==110000:
                new_location[n]='北京'
            if new_location[n]==120000:
                new_location[n]='天津'
            if new_location[n]==130000:
                new_location[n]='河北'
            if new_location[n]==140000:
                new_location[n]='山西'
            if new_location[n]==150000:
                new_location[n]='内蒙古'
            if new_location[n]==210000:
                new_location[n]='辽宁'
            if new_location[n]==220000:
                new_location[n]='吉林'
            if new_location[n]==230000:
                new_location[n]='黑龙江'
            if new_location[n]==310000:
                new_location[n]='上海'
            if new_location[n]==320000:
                new_location[n]='江苏'
            if new_location[n]==330000:
                new_location[n]='浙江'
            if new_location[n]==340000:
                new_location[n]='安徽'
            if new_location[n]==350000:
                new_location[n]='福建'
            if new_location[n]==360000:
                new_location[n]='江西'
            if new_location[n]==370000:
                new_location[n]='山东'
            if new_location[n]==410000:
                new_location[n]='河南'
            if new_location[n]==420000:
                new_location[n]='湖北'
            if new_location[n]==430000:
                new_location[n]='湖南'
            if new_location[n]==440000:
                new_location[n]='广东'
            if new_location[n]==450000:
                new_location[n]='广西'
            if new_location[n]==460000:
                new_location[n]='海南'
            if new_location[n]==500000:
                new_location[n]='重庆'
            if new_location[n]==510000:
                new_location[n]='四川'
            if new_location[n]==520000:
                new_location[n]='贵州'
            if new_location[n]==530000:
                new_location[n]='云南'
            if new_location[n]==540000:
                new_location[n]='西藏'
            if new_location[n]==610000:
                new_location[n]='陕西'
            if new_location[n]==620000:
                new_location[n]='甘肃'
            if new_location[n]==630000:
                new_location[n]='青海'
            if new_location[n]==640000:
                new_location[n]='宁夏'
            if new_location[n]==650000:
                new_location[n]='新疆'
            if new_location[n]==810000:
                new_location[n]='香港'
            if new_location[n]==820000:
                new_location[n]='澳门'
            if new_location[n]==710000:
                new_location[n]='台湾'
            if new_location[n]==0:
                new_location[n]=None
        new_location=new_location.dropna()
        new_age=new_age.dropna()
        save_location_name = path+'/locations/location'+i
        with open(save_location_name, 'w') as file_obj:
            json.dump(new_location.tolist(), file_obj,ensure_ascii=False)
        save_age_name = path+'/ages/age'+i
        with open(save_age_name, 'w') as file_obj:
            json.dump(new_age.tolist(), file_obj,ensure_ascii=False)
    except:
            i=i
# Out:
# ages
# hot_songs_users_info.py
# Include
# Lib
# locations
# New Boy.json
# pyvenv.cfg
# Scripts
# singer_top_song_users.py
# UsersInfo.py
# UserTest.py
# 你是年少的欢喜.json
# 倾尽天下.json
# 假装 (吉他版).json
# 哪里都是你.json
# 嘉宾.json
# 四季予你.json
# 我们俩.json
# 晚安.json
# 晚风.json
# 江南.json
# 海底.json
# 清明雨上.json
# 烟火里的尘埃.json
# 热爱105°C的你.json
# 爱情转移.json
# 生活在别处的你 Another me.json
# 等风起.json
# 纵横四海.json
# 给你呀（又名：for ya）.json
# 起风了.json
# 超能力.json
# 还是会想你.json
# 这世界那么多人.json
# 都市丽人生存报告.json
# 风吹一夏.json
